# %%
# Import library yang diperlukan
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import pickle

# %%
# Membaca dataset
dataservis = pd.read_csv('laporan_perbaikan.csv')

# %%
#Menampilkan sampel data 5 teratas
dataservis.head()
# Out:
#   no  kode                   nama_kode   keterangan_kerusakan  \
# 0  1   0.0     Cleaning Unit / Repasta        Cleaning Laptop
# 1  2   1.0      Install ulang OS / App  Install Ulang Windows
# 2  3   8.0     Service Kerusakan Mayor           Ganti Engsel
# 3  4   3.0  Instalasi Storage SSD/ HDD              Ganti SSD
# 4  5   5.0            Service Keyboard         Ganti Keyboard
#
#    tingkat_kerusakan  tarif_perbaikan  harga_sparepart  lama_perbaikan  \
# 0                3.0         120000.0              0.0             1.0
# 1                1.0          30000.0          50000.0             1.0
# 2                4.0         200000.0         170000.0             1.0
# 3                2.0          70000.0         130000.0             1.0
# 4                2.0          70000.0          50000.0             1.0
#
#    garansi
# 0      0.0
# 1      0.0
# 2      1.0
# 3      0.0
# 4      0.0

# %%
# Sembunyikan kolom 'kode' dan 'garansi'
dataservis.drop(columns=['no','nama_kode','keterangan_kerusakan']).head()
# Out:
#    kode  tingkat_kerusakan  tarif_perbaikan  harga_sparepart  lama_perbaikan  \
# 0   0.0                3.0         120000.0              0.0             1.0
# 1   1.0                1.0          30000.0          50000.0             1.0
# 2   8.0                4.0         200000.0         170000.0             1.0
# 3   3.0                2.0          70000.0         130000.0             1.0
# 4   5.0                2.0          70000.0          50000.0             1.0
#
#    garansi
# 0      0.0
# 1      0.0
# 2      1.0
# 3      0.0
# 4      0.0

# %%
# Check for remaining missing values
print("Missing values after dropping rows:")
print(dataservis.isnull().sum())
# Out:
# Missing values after dropping rows:
# no                      0
# kode                    1
# nama_kode               1
# keterangan_kerusakan    1
# tingkat_kerusakan       1
# tarif_perbaikan         1
# harga_sparepart         1
# lama_perbaikan          1
# garansi                 1
# dtype: int64

# %%
# Handle remaining missing values by dropping rows with NaNs
dataservis.dropna(inplace=True) # Menghapus baris yang memiliki nilai NaN

# %%
# Definisikan variabel independen dan dependen
X = dataservis[['kode','tingkat_kerusakan', 'harga_sparepart','lama_perbaikan','garansi' ,]]
Y = dataservis['tarif_perbaikan']

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
# Split data menjadi data training dan testing, test_size=0.3 berarti 30% dari
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=42)

# %%
# Buat dan latih model regresi linear
regression_model = LinearRegression()
regression_model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
# Evaluasi model
Y_pred = regression_model.predict(X_test)
mse = mean_squared_error(Y_test, Y_pred)
r2 = r2_score(Y_test, Y_pred)
print(f'MSE (Mean Square Error): {mse}')
print(f'R2 Score: {r2}')
# Out:
# MSE (Mean Square Error): 944448621.686632
# R2 Score: 0.7493209178082458

# %%
# Cetak koefisien regresi
print('Koefisien Regresi:')
print(f'Kode: {regression_model.coef_[0]}')
print(f'Tingkat Kerusakan: {regression_model.coef_[1]}')
print(f'Harga Sparepart: {regression_model.coef_[2]}')
print(f'Lama Perbaikan: {regression_model.coef_[3]}')
print(f'Garansi: {regression_model.coef_[4]}')
print(f'Intercept: {regression_model.intercept_}')
# Out:
# Koefisien Regresi:
# Kode: -1968.198351447694
# Tingkat Kerusakan: 75059.55585971421
# Harga Sparepart: -0.02150429258472286
# Lama Perbaikan: 24267.572798443987
# Garansi: 3538.503858229751
# Intercept: -67030.92146278647

# %%
# Gunakan model untuk memprediksi tarif perbaikan
kode = 6
tingkat_kerusakan = 5
harga_sparepart = 450000
lama_perbaikan = 1
garansi = 1
prediksi_tarif = regression_model.predict([[kode, tingkat_kerusakan, harga_sparepart, lama_perbaikan, garansi]])
print(f'Tarif perbaikan prediksi: Rp {prediksi_tarif[0]:,.2f}')
# Out:
# Tarif perbaikan prediksi: Rp 314,586.81
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
